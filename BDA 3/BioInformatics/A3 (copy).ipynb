# %%
import numpy as np
import random
import string
import matplotlib.pyplot as plt
from Bio.Seq import Seq
from Bio.Alphabet import generic_dna

# %% [markdown]
# # Problem 1:

# %%
lst = list(["A","U","G","C"]) #each letter represents Alanine, Glycine, Cysteine and Threonine.
n=100
String1 = "".join(random.choice(lst) for i in range(n))
String2 = "".join(random.choice(lst) for i in range(n))
seq1 = Seq(String1, generic_dna)
seq2 = Seq(String2, generic_dna)
print("Sequence 1=",seq1)
print("Sequence 2=",seq2)
# Out:
# Sequence 1= GCUACGACGCAGUUGUGAAUCUACGGAUGCUUACGGCUUGAGCAUUUCCGUAUAAACAACGGGCCACACAGUGUUAGGGUGAAAGUAAGCACAAAGAAUA
# Sequence 2= CACAAAGAUAGGCGCCUGGGUGUGAAGCAUGUCAUUUAAGUCAGUGCAAACUCGAUGCGUCAAGCUAGCAGAAGAGCAGAUGCUCUGGCGACGAACAUUU

# %%
from Bio import SeqIO

with open("ls_orchid.fasta") as in_handle:
    record_iterator = SeqIO.parse(in_handle, "fasta")
    rec_one = next(record_iterator)
    rec_two = next(record_iterator)

seq1 = str(rec_one.seq).upper()
seq2 = str(rec_two.seq).upper()
seq2=seq2[:-13]

# %%
"""seq1='AGUCGGU'
seq2='AGGUCAG'
print(len(seq1))
print(len(seq2))"""
# Out:
# "seq1='CAUGCCAG'\nseq2='GAUACCAA'\nprint(len(seq1))\nprint(len(seq2))"

# %%
seq1='AGUCGGU'
seq2='AGGUCAG'

# %% [markdown]
# ## Part 1.1:
# Construct two sequences with equal length of 100 nt by choosing A, U, G, C randomly

# %%
l1=list(seq1)
l2=list(seq2)
xlist=[]
ylist=[]
for i in range(len(l1)):        
        for j in range(len(l2)):
            if(l1[i]==l2[j]):                
                xlist.append(i)
                ylist.append(j)

# %%
f = plt.figure(figsize=(n/5,n/5))
plt.scatter(xlist,ylist)

xt=plt.xticks(np.arange(len(list(seq1))),list(seq1))
yt=plt.yticks(np.arange(len(list(seq2))),list(seq2))


plt.xlabel("Sequance 1")
plt.ylabel("Sequance 2")
plt.title("Dot Plot")
plt.grid()
plt.savefig('dotplot.jpg',dpi=300)
plt.show()

# %% [markdown]
# ## Part 2:
# Find the most similar region of the aligned sequences.

# %%
l1=list(seq1)
l2=list(seq2)
xlist=[]
ylist=[]
for i in range(len(l1)):        
            if(l1[i]==l2[i]):                
                xlist.append(i)

# %%
def groupSequence(lst): 
    res = [[lst[0]]] 
    for i in range(1, len(lst)): 
        if lst[i-1]+1 == lst[i]: 
            res[-1].append(lst[i]) 
        else: 
            res.append([lst[i]]) 
    return res

# %%
temp=[len(i) for i in groupSequence(xlist)]
maxpos = temp.index(max(temp))  

seq3=[seq1[i] for i in groupSequence(xlist)[maxpos]]
region="".join(seq3)

# %%
f = plt.figure(figsize=(n/5,n/5))
plt.scatter(xlist,xlist)

for i in groupSequence(xlist):    
    plt.plot(i,i)

xt=plt.xticks(np.arange(len(list(seq1))),list(seq1))
yt=plt.yticks(np.arange(len(list(seq2))),list(seq2))


plt.xlabel("Sequance 1")
plt.ylabel("Sequance 2")
plt.title("One-One Plot (Most Similar Region is '{}')".format(region))
plt.grid()
plt.savefig('oneoneplot.jpg',dpi=300)
plt.show()

# %% [markdown]
# # Problem 2:

# %%
ws=10
thresold=8
l1=list(seq1)
l2=list(seq2)

seq11 = ["".join(l1[i:i+ws]) for i in range(0, len(l1)) if(len(l1[i:i+ws])==ws)] 
seq22 = ["".join(l2[i:i+ws]) for i in range(0, len(l2)) if(len(l2[i:i+ws])==ws)] 

print(seq11)
print(seq22)
# Out:
# ['CGTAACAAGG', 'GTAACAAGGT', 'TAACAAGGTT', 'AACAAGGTTT', 'ACAAGGTTTC', 'CAAGGTTTCC', 'AAGGTTTCCG', 'AGGTTTCCGT', 'GGTTTCCGTA', 'GTTTCCGTAG', 'TTTCCGTAGG', 'TTCCGTAGGT', 'TCCGTAGGTG', 'CCGTAGGTGA', 'CGTAGGTGAA', 'GTAGGTGAAC', 'TAGGTGAACC', 'AGGTGAACCT', 'GGTGAACCTG', 'GTGAACCTGC', 'TGAACCTGCG', 'GAACCTGCGG', 'AACCTGCGGA', 'ACCTGCGGAA', 'CCTGCGGAAG', 'CTGCGGAAGG', 'TGCGGAAGGA', 'GCGGAAGGAT', 'CGGAAGGATC', 'GGAAGGATCA', 'GAAGGATCAT', 'AAGGATCATT', 'AGGATCATTG', 'GGATCATTGA', 'GATCATTGAT', 'ATCATTGATG', 'TCATTGATGA', 'CATTGATGAG', 'ATTGATGAGA', 'TTGATGAGAC', 'TGATGAGACC', 'GATGAGACCG', 'ATGAGACCGT', 'TGAGACCGTG', 'GAGACCGTGG', 'AGACCGTGGA', 'GACCGTGGAA', 'ACCGTGGAAT', 'CCGTGGAATA', 'CGTGGAATAA', 'GTGGAATAAA', 'TGGAATAAAC', 'GGAATAAACG', 'GAATAAACGA', 'AATAAACGAT', 'ATAAACGATC', 'TAAACGATCG', 'AAACGATCGA', 'AACGATCGAG', 'ACGATCGAGT', 'CGATCGAGTG', 'GATCGAGTGA', 'ATCGAGTGAA', 'TCGAGTGAAT', 'CGAGTGAATC', 'GAGTGAATCC', 'AGTGAATCCG', 'GTGAATCCGG', 'TGAATCCGGA', 'GAATCCGGAG', 'AATCCGGAGG', 'ATCCGGAGGA', 'TCCGGAGGAC', 'CCGGAGGACC', 'CGGAGGACCG', 'GGAGGACCGG', 'GAGGACCGGT', 'AGGACCGGTG', 'GGACCGGTGT', 'GACCGGTGTA', 'ACCGGTGTAC', 'CCGGTGTACT', 'CGGTGTACTC', 'GGTGTACTCA', 'GTGTACTCAG', 'TGTACTCAGC', 'GTACTCAGCT', 'TACTCAGCTC', 'ACTCAGCTCA', 'CTCAGCTCAC', 'TCAGCTCACC', 'CAGCTCACCG', 'AGCTCACCGG', 'GCTCACCGGG', 'CTCACCGGGG', 'TCACCGGGGG', 'CACCGGGGGC', 'ACCGGGGGCA', 'CCGGGGGCAT', 'CGGGGGCATT', 'GGGGGCATTG', 'GGGGCATTGC', 'GGGCATTGCT', 'GGCATTGCTC', 'GCATTGCTCC', 'CATTGCTCCC', 'ATTGCTCCCG', 'TTGCTCCCGT', 'TGCTCCCGTG', 'GCTCCCGTGG', 'CTCCCGTGGT', 'TCCCGTGGTG', 'CCCGTGGTGA', 'CCGTGGTGAC', 'CGTGGTGACC', 'GTGGTGACCC', 'TGGTGACCCT', 'GGTGACCCTG', 'GTGACCCTGA', 'TGACCCTGAT', 'GACCCTGATT', 'ACCCTGATTT', 'CCCTGATTTG',
GA', 'AAAATCAGAG', 'AAATCAGAGG', 'AATCAGAGGG', 'ATCAGAGGGG', 'TCAGAGGGGC', 'CAGAGGGGCA', 'AGAGGGGCAG', 'GAGGGGCAGT', 'AGGGGCAGTA', 'GGGGCAGTAT', 'GGGCAGTATG', 'GGCAGTATGC', 'GCAGTATGCT', 'CAGTATGCTA', 'AGTATGCTAC', 'GTATGCTACT', 'TATGCTACTG', 'ATGCTACTGA', 'TGCTACTGAG', 'GCTACTGAGC', 'CTACTGAGCA', 'TACTGAGCAT', 'ACTGAGCATG', 'CTGAGCATGC', 'TGAGCATGCC', 'GAGCATGCCA', 'AGCATGCCAG', 'GCATGCCAGT', 'CATGCCAGTG', 'ATGCCAGTGA', 'TGCCAGTGAA', 'GCCAGTGAAT', 'CCAGTGAATT', 'CAGTGAATTT', 'AGTGAATTTT', 'GTGAATTTTT', 'TGAATTTTTA', 'GAATTTTTAT', 'AATTTTTATG', 'ATTTTTATGA', 'TTTTTATGAC', 'TTTTATGACT', 'TTTATGACTC', 'TTATGACTCT', 'TATGACTCTC', 'ATGACTCTCG', 'TGACTCTC ...

# %%
l12=seq11[0]
l13=seq22[0]
seq111 = ["".join(l12[i:i+thresold]) for i in range(0, len(l12)) if(len(l12[i:i+thresold])==thresold)] 
seq112 = ["".join(l13[i:i+thresold]) for i in range(0, len(l13)) if(len(l12[i:i+thresold])==thresold)] 
print(seq111,seq112)
# Out:
# ['CGTAACAA', 'GTAACAAG', 'TAACAAGG'] ['CGTAACAA', 'GTAACAAG', 'TAACAAGG']

# %%
x=[]
y=[]
for i in range(len(seq11)):    
    for j in range(len(seq22)):
        l1=seq11[i]
        l2=seq22[j]
        t1 = ["".join(l1[i:i+thresold]) for i in range(0, len(l1)) if(len(l1[i:i+thresold])==thresold)] 
        t2 = ["".join(l2[i:i+thresold]) for i in range(0, len(l2)) if(len(l2[i:i+thresold])==thresold)] 
        
        for k in range(len(t1)):
            if(t1[k]==t2[k]):
                #print(i,j,seq11[i],seq22[j],t1,t2,len(t2))
                x.append(seq11.index(seq11[i]))
                y.append(seq22.index(seq22[j]))

# %%
"""x=[]
y=[]
for i in range(len(seq11)):    
    for j in range(len(seq22)):
        count=0
        for k in range(ws):
            #print(i,j,seq11[i],seq22[j])
            if(seq11[i][k]==seq22[j][k]):
                count+=1
        if(count>=thresold):
            #print(seq11[i],seq22[j])
            x.append(seq11.index(seq11[i]))
            y.append(seq22.index(seq22[j])) """
# Out:
# 'x=[]\ny=[]\nfor i in range(len(seq11)):    \n    for j in range(len(seq22)):\n        count=0\n        for k in range(ws):\n            #print(i,j,seq11[i],seq22[j])\n            if(seq11[i][k]==seq22[j][k]):\n                count+=1\n        if(count>=thresold):\n            #print(seq11[i],seq22[j])\n            x.append(seq11.index(seq11[i]))\n            y.append(seq22.index(seq22[j])) '

# %%
f = plt.figure(figsize=(5,5))
plt.scatter(x,y)

#xt=plt.xticks(np.arange(len(list(seq11))),list(seq11),rotation=90)
#yt=plt.yticks(np.arange(len(list(seq22))),list(seq22))

plt.xlabel("Sequance 1")
plt.ylabel("Sequance 2")
plt.title("Window size = {}, thresold={}".format(ws,thresold))
plt.grid()
plt.tight_layout()
plt.savefig('oneoneplot2.jpg',dpi=300)
plt.show()
